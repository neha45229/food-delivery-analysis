# %% [markdown]
# food_delivery_analysis

# %% [markdown]
# Food Delivery Data Analysis
#
# This notebook analyzes a food delivery dataset by combining:
#
# orders.csv (transactional data)
#
# users.json (user data)
#
# restaurants.sql (restaurant data)
#
# The datasets are merged using LEFT JOINs to create a final dataset used for analytical insights.

# %%
import pandas as pd
import sqlite3

# %%
# Example structure for loading datasets

# orders = pd.read_csv("orders.csv")
# users = pd.read_json("users.json")

# conn = sqlite3.connect(":memory:")
# with open("restaurants.sql", "r") as f:
#     sql_script = f.read()
# conn.executescript(sql_script)

# restaurants = pd.read_sql("SELECT * FROM restaurants", conn)

print("Notebook setup complete")
## Conclusion

The final merged dataset enables analysis of:
- Revenue trends
- User behavior
- City-wise and cuisine-wise performance
